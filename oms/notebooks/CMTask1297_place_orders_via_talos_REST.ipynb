# %% [markdown]
# # Description

# %% [markdown]
# The notebook implements an interface proposal for placing orders via Talos API (REST).
#
# Example:
# https://github.com/talostrading/samples/blob/master/python/rfqsample/rfqsample/rest.py

# %%
# %load_ext autoreload
# %autoreload 2

import base64
import datetime
import hashlib
import hmac
import logging
import uuid
from urllib.parse import urlencode

import pandas as pd
import requests

import helpers.hdbg as hdbg
import helpers.hprint as hprint
import helpers.hsecrets as hsecret

# %%
hdbg.init_logger(verbosity=logging.DEBUG)

_LOG = logging.getLogger(__name__)

hprint.config_notebook()
# Out:
# INFO: > cmd='/venv/lib/python3.8/site-packages/ipykernel_launcher.py -f /home/.local/share/jupyter/runtime/kernel-10b82031-5398-4858-9d6c-ad784fa7a9bd.json'
# WARNING: Running in Jupyter
# DEBUG Effective logging level=10
# DEBUG Shut up 78 modules: asyncio, boto3, boto3, boto3.resources, boto3.resources, boto3.resources.action, boto3.resources.action, boto3.resources.base, boto3.resources.base, boto3.resources.collection, boto3.resources.collection, boto3.resources.factory, boto3.resources.factory, boto3.resources.model, boto3.resources.model, botocore, botocore, botocore.args, botocore.args, botocore.auth, botocore.auth, botocore.awsrequest, botocore.awsrequest, botocore.client, botocore.client, botocore.compat, botocore.compat, botocore.configprovider, botocore.configprovider, botocore.credentials, botocore.credentials, botocore.discovery, botocore.discovery, botocore.endpoint, botocore.endpoint, botocore.handlers, botocore.handlers, botocore.history, botocore.history, botocore.hooks, botocore.hooks, botocore.httpsession, botocore.httpsession, botocore.loaders, botocore.loaders, botocore.monitoring, botocore.monitoring, botocore.paginate, botocore.paginate, botocore.parsers, botocore.parsers, botocore.regions, botocore.regions, botocore.response, botocore.response, botocore.retries, botocore.retries, botocore.retries.adaptive, botocore.retries.adaptive, botocore.retries.special, botocore.retries.special, botocore.retries.standard, botocore.retries.standard, botocore.retryhandler, botocore.retryhandler, botocore.session, botocore.session, botocore.utils, botocore.utils, botocore.waiter, botocore.waiter, urllib3, urllib3.connection, urllib3.connectionpool, urllib3.poolmanager, urllib3.response, urllib3.util, urllib3.util.retry
# DEBUG matplotlib data path: /venv/lib/python3.8/site-packages/matplotlib/mpl-data
# DEBUG CONFIGDIR=/home/.config/matplotlib
# DEBUG interactive is False
# DEBUG platform is linux
# DEBUG loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_warnings', '_io', 'marshal', 'posix', '_frozen_importlib_external', '_thread', '_weakref', 'time', 'zipimport', '_codecs', 'codecs', 'encodings.aliases', 'encodings', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', '_abc', 'abc', 'io', '_stat', 'stat', '_collections_abc', 'genericpath', 'posixpath', 'os.path', 'os', '_sitebuiltins', '_locale', '_bootlocale', 'types', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib', 'importlib.machinery', 'importlib.abc', '_operator', 'operator', 'keyword', '_heapq', 'heapq', 'itertools', 'reprlib', '_collections', 'collections', '_functools', 'functools', 'contextlib', 'importlib.util', 'mpl_toolkits', 'sitecustomize', 'site', '_weakrefset', 'weakref', 'pkgutil', 'runpy', 'enum', '_sre', 'sre_constants', 'sre_parse', 'sre_compile', 'copyreg', 're', 'ipykernel._version', '_json', 'json.scanner', 'json.decoder', 'json.encoder', 'json', 'errno', 'signal', 'threading', '_posixsubprocess', 'select', 'collections.abc', 'math', 'selectors', 'subprocess', 'typing.io', 'typing.re', 'typing', 'jupyter_client._version', '_ast', 'ast', '_opcode', 'opcode', 'dis', 'token', 'tokenize', 'linecache', 'inspect', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.traitlets', 'copy', 'traitlets.utils.decorators', 'traitlets._version', 'traitlets', 'concurrent', 'traceback', '_string', 'string', 'atexit', 'logging', 'concurrent.futures._base', 'concurrent.futures', '_socket', 'socket', '_ssl', '_struct', 'struct', 'binascii', 'base64', 'ssl', 'asyncio.constants', 'asyncio.format_helpers', 'asyncio.base_futures', 'asyncio.log', 'asyncio.coroutines', '_contextvars', 'contextvars', 'asyncio.exceptions', 'asyncio.base_tasks', '_asyncio', 'asyncio.events', 'asyncio.futures', 'asyncio.protocols', 'asyncio.transports', 'asyncio.sslproto', 'asyncio.locks', 'asyncio.tasks', 'asyncio.staggered', 'asyncio.trsock', 'asyncio.base_events', 'asyncio.runners', 'asyncio.queues', 'asyncio.streams', 'asyncio.subprocess', 'asyncio.base_subprocess', 'asyncio.selector_events', 'asyncio.unix_events', 'asyncio', '_queue', 'queue', 'platform', '_ctypes', 'ctypes._endian', 'ctypes', 'zmq.backend.select', 'cython_runtime', 'zmq.backend.cython.constants', '_cython_0_29_24', 'zmq.backend.cython.error', 'zmq.error', 'zmq.backend.cython.message', 'zmq.backend.cython.context', '_bisect', 'bisect', '_sha512', '_random', 'random', '_compat_pickle', '_pickle', 'pickle', 'zmq.backend.cython.socket', 'zmq.backend.cython.utils', 'zmq.backend.cython._poll', 'zmq.backend.cython._version', 'zmq.backend.cython._device', 'zmq.backend.cython._proxy_steerable', 'zmq.backend.cython', 'zmq.backend', 'zmq.utils', 'zmq.utils.constant_names', 'zmq.sugar.constants', 'zmq.sugar.attrsettr', 'zmq.sugar.poll', 'zmq.utils.jsonapi', 'zmq.utils.strtypes', 'zmq.sugar.socket', 'zmq.sugar.context', 'zmq.sugar.frame', 'zmq.sugar.tracker', 'zmq.sugar.version', 'zmq.sugar.stopwatch', 'zmq.sugar', 'zmq', 'zmq._future', 'zmq.asyncio', 'jupyter_client.channelsabc', '_hashlib', '_blake2', '_sha3', 'hashlib', 'hmac', 'pprint', '_datetime', 'datetime', 'locale', 'gettext', 'argparse', 'traitlets.config.loader', 'textwrap', 'traitlets.utils.text', 'traitlets.config.configurable', 'traitlets.config.application', 'traitlets.config', 'traitlets.log', '__future__', 'tornado', 'logging.handlers', 'html.entities', 'html', 'urllib', 'urllib.parse', 'array', 'zlib', 'tornado.speedups', 'tornado.util', 'tornado.escape', 'colorama.ansi', 'colorama.win32', 'colorama.winterm', 'colorama.ansitowin32', 'colorama.initialise', 'colorama', '_curses', 'curses', 'tornado.log', 'numbers', 'tornado.concurrent', 'tornado.ioloop', 'tornado.platform', 'tornado.gen', 'tornado.platform.asyncio', 'zmq.eventloop.ioloop', 'zmq.eventloop', 'zmq.eventloop.zmqstream', 'ju ...
# DEBUG CACHEDIR=/home/.cache/matplotlib
# DEBUG font search path [PosixPath('/venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf'), PosixPath('/venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/afm'), PosixPath('/venv/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts')]
# INFO  generated new fontManager
# DEBUG Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG Loaded backend module://matplotlib_inline.backend_inline version unknown.
# WARNING: Disabling annoying warnings

# %% [markdown]
# ## Functions

# %%
def calculate_signature(api_secret, parts):
    """
    A signature required for some types of GET and POST requests.
    """
    payload = "\n".join(parts)
    hash = hmac.new(
        api_secret.encode("ascii"), payload.encode("ascii"), hashlib.sha256
    )
    hash.hexdigest()
    signature = base64.urlsafe_b64encode(hash.digest()).decode()
    return signature


def timestamp_to_tz_naive_ISO_8601(timestamp: pd.Timestamp) -> str:
    """
    Transform Timestamp into a string in format accepted by Talos API.

    Example:
    2019-10-20T15:00:00.000000Z

    Note: microseconds must be included.
    """
    # hdateti.dassert_is_tz_naive(timestamp)
    timestamp_iso_8601 = timestamp.isoformat(timespec="microseconds") + "Z"
    return timestamp_iso_8601


def get_orders(
    endpoint: str, path: str, public_key: str, secret_key: str
) -> pd.DataFrame:
    """
    Load data from given path.

    Loads all orders up to the moment of request
    """
    utc_datetime = datetime.datetime.utcnow().strftime(
        "%Y-%m-%dT%H:%M:%S.000000Z"
    )
    # TODO(Danya): Add time query (startDate and endDate)
    # TODO(Danya): Factor out the general form of a GET request (common with OHLCV)
    # TODO(Danya): Factor out the general part of TALOS authorization.
    # Note: some kind of query is required.
    query = {"EndDate": utc_datetime}
    query_string = urlencode(query)
    print(utc_datetime)
    get_request_parts = ["GET", utc_datetime, endpoint, path, query_string]
    signature = calculate_signature(secret_key, get_request_parts)
    # TODO(*): Get secrets from hsecrets.
    headers = {
        "TALOS-KEY": public_key,  # API public key
        "TALOS-SIGN": signature,  # an encoded secret key + request
        "TALOS-TS": utc_datetime,  # Time of request UTC.
    }
    # TODO(Danya): Factor out
    url = f"https://{endpoint}{path}?{query_string}"
    print(url)
    r = requests.get(url=url, headers=headers)
    if r.status_code == 200:
        data = r.json()
    else:
        raise Exception(f"{r.status_code}: {r.text}")
    return data


def get_talos_api_keys(mode: str = "sandbox"):
    if mode == "sandbox":
        api_keys = hsecret.get_secret("talos_sandbox")
    return api_keys


def get_cl_ord_id():
    """
    Create a ClOrdID for the POST request.
    """
    return str(uuid.uuid4())


def create_order(timestamp_ISO8601: str):
    # TODO(Danya): Add arguments: quantity, markets (exchanges), order type, etc.
    # TODO(Danya): required types of order: limit, VWAP, TWAP; TimeInForce should have "GoodUntil" passed.
    order = {
        "ClOrdID": get_cl_ord_id(),
        "Markets": ["binance"],
        "OrderQty": "1.0000",
        "Symbol": "BTC-USDT",
        "Currency": "BTC",
        "TransactTime": timestamp_ISO8601,  # Should always be the utcnow() with Talos date formatting.
        "OrdType": "Limit",
        "TimeInForce": "GoodTillCancel",
        "Price": "5.81",
        "Side": "Buy",
    }
    return order


def post_order(endpoint: str, path: str, public_key: str, secret_key: str):
    # TODO(Danya): Factor out the statement.
    utc_datetime = datetime.datetime.utcnow().strftime(
        "%Y-%m-%dT%H:%M:%S.000000Z"
    )
    parts = [
        "POST",
        utc_datetime,
        "tal-87.sandbox.talostrading.com",
        "/v1/orders",
    ]
    # TODO(Danya): Create order from outside with specific arguments
    order = create_order(utc_datetime)
    print(order)
    body = json.dumps(order)
    parts.append(body)
    # Enciode request with secret key.
    signature = calculate_signature(secret_key, parts)
    headers = {
        "TALOS-KEY": public_key,
        "TALOS-SIGN": signature,
        "TALOS-TS": utc_datetime,
    }
    # Create a POST request.
    url = f"https://{endpoint}{path}"
    r = requests.post(url=url, data=body, headers=headers)
    if r.status_code != 200:
        Exception(f"{r.status_code}: {r.text}")
    return r.status_code

# %% [markdown]
# ### Setup

# %%
# Imitation of script input parameters.
# Common elements of both GET and POST requests.
api_keys = get_talos_api_keys()
endpoint = "tal-87.sandbox.talostrading.com"  # our sandbox endpoint
path = "/v1/orders"  # path for all data related to placin orders

# %% [markdown]
# ### How to load orders?
# https://docs.talostrading.com/#get-an-order-rest

# %%
get_orders(endpoint, path, api_keys["apiKey"], api_keys["secret"])
# Out:
# 2022-03-08T13:20:47.000000Z
# https://tal-87.sandbox.talostrading.com/v1/orders?EndDate=2022-03-08T13%3A20%3A47.000000Z
# {'type': 'Order',
#  'ts': '2022-03-08T13:20:47.263672Z',
#  'data': [{'Timestamp': '2022-02-28T11:38:53.403035Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'f378848a-27e2-4230-97d9-1cd94316e42e',
#    'ClOrdID': '01499b80-988b-11ec-bccb-4d5dd7af3e3f',
#    'SubmitTime': '2022-02-28T11:38:53.309023Z',
#    'ExecID': '6838b88b-3ec1-41e0-9e68-a68ff4d1b0a9',
#    'Side': 'Buy',
#    'TransactTime': '2022-02-28T11:38:53.370360Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '38244.06000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '38244.06000000',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '38244.06000000',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'SessionID': '19JQ175240800',
#    'ExpectedFillPrice': '38240.39',
#    'ExpectedFillQty': '1.00000000',
#    'Strategy': 'Limit',
#    'AvgPxAllIn': '38244.06000000',
#    'Revision': 4,
#    'LastRequestTimestamp': '2022-02-28T11:38:53.309023Z',
#    'Markets': [{'Market': 'coinbase',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'coinbase/coinbase'},
#     {'Market': 'binance',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'},
#     {'Market': 'kraken',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'kraken/kraken'},
#     {'Market': 'poloniex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'poloniex/poloniex'},
#     {'Market': 'bitstamp',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'bitstamp/bitstamp'},
#     {'Market': 'bitfinex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'bitfinex/bitfinex',
#      'Text': 'Market data is offline'},
#     {'Market': 'alameda',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'alameda/alameda',
#      'Text': 'Market data is offline'},
#     {'Market': 'cumberland',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'cumberland/cumberland'},
#     {'Market': 'b2c2',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'b2c2/b2c2'},
#     {'Market': 'galaxy',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000000',
#      'CumAmt': '38244.0600000000',
#      'CumFee': '0',
#      'AvgPx': '38244.06000000',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'galaxy/galaxy'},
#     {'Market': 'ftx-otc',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx-otc/ftx-otc',
#      'Text': 'Market data is offline'},
#     {'Market': 'binance_us',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance_us/binance_us'},
#     {'Market': 'dvchain',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'dvchain/dvchain'},
#     {'Market': 'ftx_us',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx_us/ftx_us'},
#     {'Market': 'ftx',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx/ftx'},
#     {'Market': 'jump',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'jump/jump'},
#     {'Market': 'wintermute',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'wintermute/wintermute'},
#     {'Market': 'okcoin',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataStale',
#      'LegIndex': 0,
#      'MarketAccount': 'okcoin/okcoin',
#      'Text': 'Market data is stale'},
#     {'Market': 'okex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataStale',
#      'LegIndex': 0,
#      'MarketAccount': 'okex/okex',
#      'Text': 'Market data is stale'},
#     {'Market': 'osl_am',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'osl_am/osl_am'}],
#    'Parameters': {'ErrorAction': 'Pause'}},
#   {'Timestamp': '2022-03-02T08:59:57.159773Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '0b4401a4-6af0-46e6-ac0d-fccd8d73d420',
#    'ClOrdID': '4828d500-997d-11ec-bd4e-43610f14df43',
#    'SubmitTime': '2022-03-01T16:33:10.354386Z',
#    'ExecID': '5dd0ff19-6284-4b14-b095-bac01113faea',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-02T08:59:57.109000Z',
#    'OrdStatus': 'Canceled',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '43.50000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'SessionID': '19K35GBXW0800',
#    'ExpectedFillPrice': '43486.70',
#    'ExpectedFillQty': '1.00000000',
#    'Strategy': 'Limit',
#    'Revision': 4,
#    'LastRequestTimestamp': '2022-03-01T16:33:10.354386Z',
#    'Markets': [{'Market': 'coinbase',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'coinbase/coinbase'},
#     {'Market': 'binance',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'},
#     {'Market': 'kraken',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'kraken/kraken'},
#     {'Market': 'poloniex',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'poloniex/poloniex'},
#     {'Market': 'bitstamp',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'bitstamp/bitstamp'},
#     {'Market': 'bitfinex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'bitfinex/bitfinex',
#      'Text': 'Market data is offline'},
#     {'Market': 'alameda',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'alameda/alameda',
#      'Text': 'Market data is offline'},
#     {'Market': 'cumberland',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'cumberland/cumberland'},
#     {'Market': 'b2c2',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'b2c2/b2c2'},
#     {'Market': 'galaxy',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'galaxy/galaxy'},
#     {'Market': 'ftx-otc',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx-otc/ftx-otc',
#      'Text': 'Market data is offline'},
#     {'Market': 'binance_us',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance_us/binance_us'},
#     {'Market': 'dvchain',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'dvchain/dvchain'},
#     {'Market': 'ftx_us',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx_us/ftx_us'},
#     {'Market': 'ftx',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx/ftx'},
#     {'Market': 'jump',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'jump/jump'},
#     {'Market': 'wintermute',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'wintermute/wintermute'},
#     {'Market': 'okcoin',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataStale',
#      'LegIndex': 0,
#      'MarketAccount': 'okcoin/okcoin',
#      'Text': 'Market data is stale'},
#     {'Market': 'okex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataStale',
#      'LegIndex': 0,
#      'MarketAccount': 'okex/okex',
#      'Text': 'Market data is stale'},
#     {'Market': 'osl_am',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'NoCrossingSize',
#      'LegIndex': 0,
#      'MarketAccount': 'osl_am/osl_am',
#      'Text': 'Order not filled'}],
#    'Text': 'Violated child order safety limit (100000), cancelling order',
#    'Parameters': {'ErrorAction': 'Pause'}},
#   {'Timestamp': '2022-03-01T17:29:46.702587Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '87706161-dd0c-41d7-a20a-43131e80e2a5',
#    'ClOrdID': '61ec2f06-f2b2-4e08-ba2d-4fb5be3391a3',
#    'SubmitTime': '2022-03-01T17:29:46.638735Z',
#    'ExecID': '4a5c3c35-2ad1-40e2-afb2-999f635bb67d',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-01T17:29:46.679000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '43481.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '43470.14997660',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '43470.14997660',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '43470.14997660',
#    'Revision': 10,
#    'LastRequestTimestamp': '2022-03-01T17:29:46.638735Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '43470.1499766000',
#      'CumFee': '0',
#      'AvgPx': '43470.1499766',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-01T17:29:54.389506Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'adeb6454-5689-4806-a0a5-51e85b46f722',
#    'ClOrdID': '61ec2f06-f2b2-4e08-ba2d-4fb5be3391a3',
#    'SubmitTime': '2022-03-01T17:29:54.389506Z',
#    'ExecID': 'b97ca122-6f31-4fa3-a803-b071f62d7ac2',
#    'Side': 'Buy',
#    'OrdStatus': 'Rejected',
#    'OrderQty': '1.0000',
#    'OrdType': 'Limit',
#    'Price': '43481.81',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'OrdRejReason': 'DuplicateOrder',
#    'DecisionStatus': 'Active',
#    'Revision': 0,
#    'Markets': [{'Market': 'binance',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}],
#    'Text': 'duplicate ClOrdID'},
#   {'Timestamp': '2022-03-02T13:36:13.859508Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '0c58a09b-3776-434e-ab7a-aecefae205cd',
#    'ClOrdID': '16becdb2-b7f5-4fab-a674-a89b34843efd',
#    'SubmitTime': '2022-03-02T09:04:04.830860Z',
#    'ExecID': 'f8064a77-f652-4aba-a7c1-dfa6ce0da254',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-02T13:36:13.849000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '43481.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '43481.71818800',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '43481.71818800',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '43481.71818800',
#    'Revision': 6,
#    'LastRequestTimestamp': '2022-03-02T09:04:04.830860Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '43481.7181880000',
#      'CumFee': '0',
#      'AvgPx': '43481.718188',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-02T09:04:13.280724Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '84bf57b3-276c-4a7b-af22-83bb8d8c8d88',
#    'ClOrdID': 'd7e966e8-0da5-4e38-89ac-fb005e6185a0',
#    'SubmitTime': '2022-03-02T09:04:13.119908Z',
#    'ExecID': 'e20fe2a9-133a-485b-8fa2-c2e8bc602ba2',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-02T09:04:13.266000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '48481.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '43855.97855570',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '43855.97855570',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '43855.97855570',
#    'Revision': 8,
#    'LastRequestTimestamp': '2022-03-02T09:04:13.119908Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '43855.9785557000',
#      'CumFee': '0',
#      'AvgPx': '43855.9785557',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.409785Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'b9e49694-054d-46f1-8ece-f16d669b7440',
#    'ClOrdID': '85963d0e-8eca-46cd-8e41-9ae20f13d036',
#    'SubmitTime': '2022-03-02T09:40:08.955900Z',
#    'ExecID': '6eb707f3-b51b-4d82-9a1e-07ba41c370d5',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.393000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T09:40:08.955900Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.412057Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'd1835866-d122-43d5-964f-e82763b63197',
#    'ClOrdID': '54bf63a1-e53f-462c-bd6d-5dae1ef00c96',
#    'SubmitTime': '2022-03-02T15:26:02.231813Z',
#    'ExecID': '09a2afac-2bf9-45ba-9d45-80fab0bd7221',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.394000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T15:26:02.231813Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.414170Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '18f08eee-d9d1-4829-b210-9a4a39315880',
#    'ClOrdID': '170046af-3f81-410a-8c5e-059109640a3d',
#    'SubmitTime': '2022-03-02T15:26:22.296114Z',
#    'ExecID': 'e7a05b12-b1d2-4ae0-ad42-825cd34afb82',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.394000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T15:26:22.296114Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.416464Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'd66bc24e-3809-482c-b9ba-286e28d10805',
#    'ClOrdID': 'f06ed92c-abad-44df-812b-7f98fdd7e915',
#    'SubmitTime': '2022-03-02T15:28:38.027359Z',
#    'ExecID': '8300f456-3108-4dff-829c-07f08ea0a8a7',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.394000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T15:28:38.027359Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.418453Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '968f27bd-60a2-4784-b7b3-bb70c76feda3',
#    'ClOrdID': '135c3dbe-669d-4416-a6e1-5273e91fb57b',
#    'SubmitTime': '2022-03-02T15:32:32.749242Z',
#    'ExecID': 'a144e146-e306-4946-9577-45b300302db1',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.394000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T15:32:32.749242Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.419963Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'ea774bbe-1aa3-4c21-9e30-25f04e4fb75e',
#    'ClOrdID': '9091f40b-0015-4025-977d-4f15b948ffab',
#    'SubmitTime': '2022-03-02T16:13:58.512856Z',
#    'ExecID': '13c5e309-7d66-44be-8947-26c11473c64e',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.395000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T16:13:58.512856Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.422171Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '2646128b-4827-4c62-bc35-75c99143b6d2',
#    'ClOrdID': '2bf2bffc-c6e7-435c-9cf4-f0b50ec7391f',
#    'SubmitTime': '2022-03-04T19:53:16.133949Z',
#    'ExecID': 'd85e27f5-57d4-45b2-8d85-2cf64ac887e2',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.397000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-04T19:53:16.133949Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.424250Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '04e2e272-4a5c-4a23-89b9-29bd9dfc8bd5',
#    'ClOrdID': 'ebfec133-7d60-4861-9f28-5acd5c3c5dc7',
#    'SubmitTime': '2022-03-04T20:05:24.814657Z',
#    'ExecID': '74752b50-029b-40e2-a28a-e30d29cec462',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.398000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-04T20:05:24.814657Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.426107Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '0440abc6-4183-4734-8890-73f190740c15',
#    'ClOrdID': '73059619-ecae-4323-a7ab-2d2056cd1612',
#    'SubmitTime': '2022-03-05T12:50:37.741176Z',
#    'ExecID': '2b4a0c11-ca64-4ca4-b8b8-c9ffedb89c09',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.400000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-05T12:50:37.741176Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.428000Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'a2528cd2-41da-477b-9bd0-dfc1e3c175f1',
#    'ClOrdID': 'ff05e796-dba3-4827-9612-fe0048c170fd',
#    'SubmitTime': '2022-03-05T15:20:22.692768Z',
#    'ExecID': 'ff952a16-18a8-49b0-867e-6787d2c9a9e0',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.401000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '0.01000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-05T15:20:22.692768Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0.01',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:50:54.400593Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '315e17ba-376c-4d87-b159-02c161596ad6',
#    'ClOrdID': '255d8d3f-affd-4545-affe-7ebf3846571f',
#    'SubmitTime': '2022-03-07T11:18:44.144639Z',
#    'ExecID': '84ee36df-821c-4581-aab6-95a696582a74',
#    'Side': 'Buy',
#    'OrdStatus': 'Canceled',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 3,
#    'LastRequestTimestamp': '2022-03-07T11:18:44.144639Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Error',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance',
#      'Text': 'Rate limit exceeded: window: 1s, threshold: 10 msgs'}],
#    'Text': 'Rate limit exceeded: window: 1s, threshold: 10 msgs on Binance'},
#   {'Timestamp': '2022-03-08T11:24:53.401716Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'ec5ce334-d43b-4381-8ab6-828fbe4fab1e',
#    'ClOrdID': 'e214938a-870d-4e62-bccf-ef54a0afec78',
#    'SubmitTime': '2022-03-08T11:24:53.350343Z',
#    'ExecID': '05a4850e-c184-4ba8-b886-58b154b060f8',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T11:24:53.397000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-08T11:24:53.350343Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T12:17:08.581242Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'ddc352d4-e42f-4306-a2ca-cef408e508cc',
#    'ClOrdID': '4a3ad58d-f1a3-4258-9837-d07f62ffc6ff',
#    'SubmitTime': '2022-03-08T12:17:08.555672Z',
#    'ExecID': 'cab83652-a681-4888-90aa-68f8aa4138ca',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T12:17:08.565000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-08T12:17:08.555672Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T12:52:10.068543Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '59d91b26-639e-41ed-ab86-801af5b2666c',
#    'ClOrdID': '7cfbb8b3-2d70-4610-8bc8-c7e75e4d1916',
#    'SubmitTime': '2022-03-08T12:52:10.036627Z',
#    'ExecID': '88841e6d-a672-49f1-a5f2-34a6e82b5edf',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T12:52:10.053000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-08T12:52:10.036627Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T12:56:21.067633Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '1507158d-726a-47d1-8c44-69b54a2f74a7',
#    'ClOrdID': '2096024d-c3f4-49ae-9fbe-68ac1b85cade',
#    'SubmitTime': '2022-03-08T12:56:21.029282Z',
#    'ExecID': 'e0c0a5d5-b416-4b01-ad1d-10fb843953a7',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T12:56:21.046000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-08T12:56:21.029282Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T12:58:56.166466Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '7cac4a94-3758-4101-b5ea-3fca3c6ce24e',
#    'ClOrdID': 'f0f15269-00e4-46f6-b836-c863f80dc19b',
#    'SubmitTime': '2022-03-08T12:58:56.027877Z',
#    'ExecID': '73e1aeed-f5b1-49b9-a3c4-eee6fec09db6',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T12:58:56.145000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '38817.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '38799.53372950',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '38799.53372950',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '38799.53372950',
#    'Revision': 5,
#    'LastRequestTimestamp': '2022-03-08T12:58:56.027877Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '38799.5337295000',
#      'CumFee': '0',
#      'AvgPx': '38799.5337295',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T13:01:57.817285Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'dd0f57e8-f863-49bc-8a8e-ee2915f46e16',
#    'ClOrdID': '4aa4df08-8e0d-4897-86a6-9dac7295a48b',
#    'SubmitTime': '2022-03-08T13:01:57.754796Z',
#    'ExecID': '57f3bcc2-ecf2-4353-a87e-fdc5fa36e090',
#    'Side': 'Sell',
#    'TransactTime': '2022-03-08T13:01:57.782000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '38773.97591690',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '38773.97591690',
#    'CumFee': '7.754795183380',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '38766.22112172',
#    'Revision': 15,
#    'LastRequestTimestamp': '2022-03-08T13:01:57.754796Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '38773.9759169000',
#      'CumFee': '7.75479518338',
#      'AvgPx': '38773.9759169',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T13:12:30.972317Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '988fdc09-7526-433b-b72a-754c21b7a3ca',
#    'ClOrdID': '20057d39-91f0-43e2-9c50-90f2cc328f1c',
#    'SubmitTime': '2022-03-08T13:12:30.799817Z',
#    'ExecID': '806f3ee3-3f33-4134-8da5-651fe0080f58',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T13:12:30.959000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '39000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '38720.11000000',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '38720.11000000',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '38720.11000000',
#    'Revision': 4,
#    'LastRequestTimestamp': '2022-03-08T13:12:30.799817Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '38720.1100000000',
#      'CumFee': '0',
#      'AvgPx': '38720.11',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T13:13:39.571444Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'aef9de69-639a-4444-87cd-023dafa1b39d',
#    'ClOrdID': '3a1b23ff-0ee0-42c3-b6cd-f249548e9092',
#    'SubmitTime': '2022-03-08T13:13:39.571444Z',
#    'ExecID': '3dbca53d-7525-4908-a3ad-2728a2cca19f',
#    'Side': 'Sell',
#    'OrdStatus': 'Rejected',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '37000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'OrdRejReason': 'BrokerOption',
#    'DecisionStatus': 'Active',
#    'Strategy': 'TWAP',
#    'Revision': 0,
#    'Markets': [{'Market': 'binance',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}],
#    'Text': 'Order duration must be at least 30s'},
#   {'Timestamp': '2022-03-08T13:14:10.727770Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '6bd333d0-4169-4297-ba81-8d2fe4106496',
#    'ClOrdID': 'f5b98b2f-b3b0-40e1-b9e6-c5319a943936',
#    'SubmitTime': '2022-03-08T13:14:10.727770Z',
#    'ExecID': '310288b0-b976-4432-a07c-29d85fb37c49',
#    'Side': 'Sell',
#    'OrdStatus': 'Rejected',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '37000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'OrdRejReason': 'BrokerOption',
#    'DecisionStatus': 'Active',
#    'Strategy': 'TWAP',
#    'Revision': 0,
#    'Markets': [{'Market': 'binance',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}],
#    'Text': 'Order duration must be at least 30s'},
#   {'Timestamp': '2022-03-08T13:19:51.615501Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '30a32467-3bf6-45c1-a944-265e720c22f2',
#    'ClOrdID': '2644df41-8aac-47e7-9fbf-0ce51d05f870',
#    'SubmitTime': '2022-03-08T13:19:51.615501Z',
#    'ExecID': '3658c9af-b154-4519-a589-e27787687c51',
#    'Side': 'Sell',
#    'OrdStatus': 'Rejected',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '37000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'OrdRejReason': 'BrokerOption',
#    'DecisionStatus': 'Active',
#    'Strategy': 'TWAP',
#    'EndTime': '2022-03-08T16:20:00.000000Z',
#    'Revision': 0,
#    'Markets': [{'Market': 'binance',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}],
#    'Text': 'Start time should be before end time'}]}

# %% [markdown]
# ### Post an order

# %%
post_order(endpoint, path, api_keys["apiKey"], api_keys["secret"])
# Out:
# {'ClOrdID': 'a08a1c85-525a-4e51-a119-af8da533c70e', 'Markets': ['binance'], 'OrderQty': '1.0000', 'Symbol': 'BTC-USDT', 'Currency': 'BTC', 'TransactTime': '2022-03-08T13:20:47.000000Z', 'OrdType': 'Limit', 'TimeInForce': 'GoodTillCancel', 'Price': '37000', 'Side': 'Sell', 'Strategy': 'TWAP', 'EndTime': '2022-03-08T16:21:00.000000Z'}
# 200

# %%
import helpers.hsecrets as hsecret
api_keys = hsecret.get_secret("talos_sandbox")

# %%
api_keys
# Out:
# {'apiKey': 'CRYEY4S913H3', 'secret': 'dkrzk9w2rncd599qp0vxz9g4zlcp382q'}

# %% [markdown]
# ## Place sell order using TWAP strategy

# %% [markdown]
# In order to specify strategy one should use param `Strategy` and choose one of the 10 options (see description in th doc: https://docs.google.com/document/d/1BPn08jDr-Rzu79KhAKFA_ZI1Vk1WtxDuLgm4N05DFRc/edit#)
#
# In this case there's a presentation of Sell order via TWAP order strategy. TWAP strategy requires param `EndTime`, while StartTime is optional.

# %%
def create_order(timestamp_ISO8601: str):
    order = {
        "ClOrdID": get_cl_ord_id(),
        "Markets": ["binance"],
        "OrderQty": "0.1000",
        "Symbol": "BTC-USDT",
        "Currency": "BTC",
        "TransactTime": timestamp_ISO8601,  # Should always be the utcnow() with Talos date formatting.
        "OrdType": "Limit",
        "TimeInForce": "GoodTillCancel",
        "Price": "37000",
        "Side": "Sell",
        "Strategy": "TWAP",
        "EndTime": "2022-03-08T16:21:00.000000Z",
        #"StartTime": "2022-03-08T16:22:00.000000Z"
    }
    return order

# %%
get_orders(endpoint, path, api_keys["apiKey"], api_keys["secret"])
# Out:
# 2022-03-08T15:59:44.000000Z
# https://tal-87.sandbox.talostrading.com/v1/orders?EndDate=2022-03-08T15%3A59%3A44.000000Z
# {'type': 'Order',
#  'ts': '2022-03-08T15:59:44.425407Z',
#  'data': [{'Timestamp': '2022-02-28T11:38:53.403035Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'f378848a-27e2-4230-97d9-1cd94316e42e',
#    'ClOrdID': '01499b80-988b-11ec-bccb-4d5dd7af3e3f',
#    'SubmitTime': '2022-02-28T11:38:53.309023Z',
#    'ExecID': '6838b88b-3ec1-41e0-9e68-a68ff4d1b0a9',
#    'Side': 'Buy',
#    'TransactTime': '2022-02-28T11:38:53.370360Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '38244.06000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '38244.06000000',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '38244.06000000',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'SessionID': '19JQ175240800',
#    'ExpectedFillPrice': '38240.39',
#    'ExpectedFillQty': '1.00000000',
#    'Strategy': 'Limit',
#    'AvgPxAllIn': '38244.06000000',
#    'Revision': 4,
#    'LastRequestTimestamp': '2022-02-28T11:38:53.309023Z',
#    'Markets': [{'Market': 'coinbase',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'coinbase/coinbase'},
#     {'Market': 'binance',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'},
#     {'Market': 'kraken',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'kraken/kraken'},
#     {'Market': 'poloniex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'poloniex/poloniex'},
#     {'Market': 'bitstamp',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'bitstamp/bitstamp'},
#     {'Market': 'bitfinex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'bitfinex/bitfinex',
#      'Text': 'Market data is offline'},
#     {'Market': 'alameda',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'alameda/alameda',
#      'Text': 'Market data is offline'},
#     {'Market': 'cumberland',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'cumberland/cumberland'},
#     {'Market': 'b2c2',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'b2c2/b2c2'},
#     {'Market': 'galaxy',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000000',
#      'CumAmt': '38244.0600000000',
#      'CumFee': '0',
#      'AvgPx': '38244.06000000',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'galaxy/galaxy'},
#     {'Market': 'ftx-otc',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx-otc/ftx-otc',
#      'Text': 'Market data is offline'},
#     {'Market': 'binance_us',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance_us/binance_us'},
#     {'Market': 'dvchain',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'dvchain/dvchain'},
#     {'Market': 'ftx_us',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx_us/ftx_us'},
#     {'Market': 'ftx',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx/ftx'},
#     {'Market': 'jump',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'jump/jump'},
#     {'Market': 'wintermute',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'wintermute/wintermute'},
#     {'Market': 'okcoin',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataStale',
#      'LegIndex': 0,
#      'MarketAccount': 'okcoin/okcoin',
#      'Text': 'Market data is stale'},
#     {'Market': 'okex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataStale',
#      'LegIndex': 0,
#      'MarketAccount': 'okex/okex',
#      'Text': 'Market data is stale'},
#     {'Market': 'osl_am',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'osl_am/osl_am'}],
#    'Parameters': {'ErrorAction': 'Pause'}},
#   {'Timestamp': '2022-03-02T08:59:57.159773Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '0b4401a4-6af0-46e6-ac0d-fccd8d73d420',
#    'ClOrdID': '4828d500-997d-11ec-bd4e-43610f14df43',
#    'SubmitTime': '2022-03-01T16:33:10.354386Z',
#    'ExecID': '5dd0ff19-6284-4b14-b095-bac01113faea',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-02T08:59:57.109000Z',
#    'OrdStatus': 'Canceled',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '43.50000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'SessionID': '19K35GBXW0800',
#    'ExpectedFillPrice': '43486.70',
#    'ExpectedFillQty': '1.00000000',
#    'Strategy': 'Limit',
#    'Revision': 4,
#    'LastRequestTimestamp': '2022-03-01T16:33:10.354386Z',
#    'Markets': [{'Market': 'coinbase',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'coinbase/coinbase'},
#     {'Market': 'binance',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'},
#     {'Market': 'kraken',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'kraken/kraken'},
#     {'Market': 'poloniex',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'poloniex/poloniex'},
#     {'Market': 'bitstamp',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'bitstamp/bitstamp'},
#     {'Market': 'bitfinex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'bitfinex/bitfinex',
#      'Text': 'Market data is offline'},
#     {'Market': 'alameda',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'alameda/alameda',
#      'Text': 'Market data is offline'},
#     {'Market': 'cumberland',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'cumberland/cumberland'},
#     {'Market': 'b2c2',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'b2c2/b2c2'},
#     {'Market': 'galaxy',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'galaxy/galaxy'},
#     {'Market': 'ftx-otc',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataOffline',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx-otc/ftx-otc',
#      'Text': 'Market data is offline'},
#     {'Market': 'binance_us',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance_us/binance_us'},
#     {'Market': 'dvchain',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'dvchain/dvchain'},
#     {'Market': 'ftx_us',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx_us/ftx_us'},
#     {'Market': 'ftx',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'ftx/ftx'},
#     {'Market': 'jump',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'jump/jump'},
#     {'Market': 'wintermute',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'wintermute/wintermute'},
#     {'Market': 'okcoin',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataStale',
#      'LegIndex': 0,
#      'MarketAccount': 'okcoin/okcoin',
#      'Text': 'Market data is stale'},
#     {'Market': 'okex',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'MarketDataStale',
#      'LegIndex': 0,
#      'MarketAccount': 'okex/okex',
#      'Text': 'Market data is stale'},
#     {'Market': 'osl_am',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'NoCrossingSize',
#      'LegIndex': 0,
#      'MarketAccount': 'osl_am/osl_am',
#      'Text': 'Order not filled'}],
#    'Text': 'Violated child order safety limit (100000), cancelling order',
#    'Parameters': {'ErrorAction': 'Pause'}},
#   {'Timestamp': '2022-03-01T17:29:46.702587Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '87706161-dd0c-41d7-a20a-43131e80e2a5',
#    'ClOrdID': '61ec2f06-f2b2-4e08-ba2d-4fb5be3391a3',
#    'SubmitTime': '2022-03-01T17:29:46.638735Z',
#    'ExecID': '4a5c3c35-2ad1-40e2-afb2-999f635bb67d',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-01T17:29:46.679000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '43481.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '43470.14997660',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '43470.14997660',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '43470.14997660',
#    'Revision': 10,
#    'LastRequestTimestamp': '2022-03-01T17:29:46.638735Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '43470.1499766000',
#      'CumFee': '0',
#      'AvgPx': '43470.1499766',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-01T17:29:54.389506Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'adeb6454-5689-4806-a0a5-51e85b46f722',
#    'ClOrdID': '61ec2f06-f2b2-4e08-ba2d-4fb5be3391a3',
#    'SubmitTime': '2022-03-01T17:29:54.389506Z',
#    'ExecID': 'b97ca122-6f31-4fa3-a803-b071f62d7ac2',
#    'Side': 'Buy',
#    'OrdStatus': 'Rejected',
#    'OrderQty': '1.0000',
#    'OrdType': 'Limit',
#    'Price': '43481.81',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'OrdRejReason': 'DuplicateOrder',
#    'DecisionStatus': 'Active',
#    'Revision': 0,
#    'Markets': [{'Market': 'binance',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}],
#    'Text': 'duplicate ClOrdID'},
#   {'Timestamp': '2022-03-02T13:36:13.859508Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '0c58a09b-3776-434e-ab7a-aecefae205cd',
#    'ClOrdID': '16becdb2-b7f5-4fab-a674-a89b34843efd',
#    'SubmitTime': '2022-03-02T09:04:04.830860Z',
#    'ExecID': 'f8064a77-f652-4aba-a7c1-dfa6ce0da254',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-02T13:36:13.849000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '43481.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '43481.71818800',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '43481.71818800',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '43481.71818800',
#    'Revision': 6,
#    'LastRequestTimestamp': '2022-03-02T09:04:04.830860Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '43481.7181880000',
#      'CumFee': '0',
#      'AvgPx': '43481.718188',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-02T09:04:13.280724Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '84bf57b3-276c-4a7b-af22-83bb8d8c8d88',
#    'ClOrdID': 'd7e966e8-0da5-4e38-89ac-fb005e6185a0',
#    'SubmitTime': '2022-03-02T09:04:13.119908Z',
#    'ExecID': 'e20fe2a9-133a-485b-8fa2-c2e8bc602ba2',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-02T09:04:13.266000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '48481.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '43855.97855570',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '43855.97855570',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '43855.97855570',
#    'Revision': 8,
#    'LastRequestTimestamp': '2022-03-02T09:04:13.119908Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '43855.9785557000',
#      'CumFee': '0',
#      'AvgPx': '43855.9785557',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.409785Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'b9e49694-054d-46f1-8ece-f16d669b7440',
#    'ClOrdID': '85963d0e-8eca-46cd-8e41-9ae20f13d036',
#    'SubmitTime': '2022-03-02T09:40:08.955900Z',
#    'ExecID': '6eb707f3-b51b-4d82-9a1e-07ba41c370d5',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.393000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T09:40:08.955900Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.412057Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'd1835866-d122-43d5-964f-e82763b63197',
#    'ClOrdID': '54bf63a1-e53f-462c-bd6d-5dae1ef00c96',
#    'SubmitTime': '2022-03-02T15:26:02.231813Z',
#    'ExecID': '09a2afac-2bf9-45ba-9d45-80fab0bd7221',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.394000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T15:26:02.231813Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.414170Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '18f08eee-d9d1-4829-b210-9a4a39315880',
#    'ClOrdID': '170046af-3f81-410a-8c5e-059109640a3d',
#    'SubmitTime': '2022-03-02T15:26:22.296114Z',
#    'ExecID': 'e7a05b12-b1d2-4ae0-ad42-825cd34afb82',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.394000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T15:26:22.296114Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.416464Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'd66bc24e-3809-482c-b9ba-286e28d10805',
#    'ClOrdID': 'f06ed92c-abad-44df-812b-7f98fdd7e915',
#    'SubmitTime': '2022-03-02T15:28:38.027359Z',
#    'ExecID': '8300f456-3108-4dff-829c-07f08ea0a8a7',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.394000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T15:28:38.027359Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.418453Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '968f27bd-60a2-4784-b7b3-bb70c76feda3',
#    'ClOrdID': '135c3dbe-669d-4416-a6e1-5273e91fb57b',
#    'SubmitTime': '2022-03-02T15:32:32.749242Z',
#    'ExecID': 'a144e146-e306-4946-9577-45b300302db1',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.394000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T15:32:32.749242Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.419963Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'ea774bbe-1aa3-4c21-9e30-25f04e4fb75e',
#    'ClOrdID': '9091f40b-0015-4025-977d-4f15b948ffab',
#    'SubmitTime': '2022-03-02T16:13:58.512856Z',
#    'ExecID': '13c5e309-7d66-44be-8947-26c11473c64e',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.395000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-02T16:13:58.512856Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.422171Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '2646128b-4827-4c62-bc35-75c99143b6d2',
#    'ClOrdID': '2bf2bffc-c6e7-435c-9cf4-f0b50ec7391f',
#    'SubmitTime': '2022-03-04T19:53:16.133949Z',
#    'ExecID': 'd85e27f5-57d4-45b2-8d85-2cf64ac887e2',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.397000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-04T19:53:16.133949Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.424250Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '04e2e272-4a5c-4a23-89b9-29bd9dfc8bd5',
#    'ClOrdID': 'ebfec133-7d60-4861-9f28-5acd5c3c5dc7',
#    'SubmitTime': '2022-03-04T20:05:24.814657Z',
#    'ExecID': '74752b50-029b-40e2-a28a-e30d29cec462',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.398000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-04T20:05:24.814657Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.426107Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '0440abc6-4183-4734-8890-73f190740c15',
#    'ClOrdID': '73059619-ecae-4323-a7ab-2d2056cd1612',
#    'SubmitTime': '2022-03-05T12:50:37.741176Z',
#    'ExecID': '2b4a0c11-ca64-4ca4-b8b8-c9ffedb89c09',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.400000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-05T12:50:37.741176Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:51:40.428000Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'a2528cd2-41da-477b-9bd0-dfc1e3c175f1',
#    'ClOrdID': 'ff05e796-dba3-4827-9612-fe0048c170fd',
#    'SubmitTime': '2022-03-05T15:20:22.692768Z',
#    'ExecID': 'ff952a16-18a8-49b0-867e-6787d2c9a9e0',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T07:51:40.401000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '0.01000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-05T15:20:22.692768Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0.01',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T07:50:54.400593Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '315e17ba-376c-4d87-b159-02c161596ad6',
#    'ClOrdID': '255d8d3f-affd-4545-affe-7ebf3846571f',
#    'SubmitTime': '2022-03-07T11:18:44.144639Z',
#    'ExecID': '84ee36df-821c-4581-aab6-95a696582a74',
#    'Side': 'Buy',
#    'OrdStatus': 'Canceled',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 3,
#    'LastRequestTimestamp': '2022-03-07T11:18:44.144639Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Canceled',
#      'OrderQty': '0',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Error',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance',
#      'Text': 'Rate limit exceeded: window: 1s, threshold: 10 msgs'}],
#    'Text': 'Rate limit exceeded: window: 1s, threshold: 10 msgs on Binance'},
#   {'Timestamp': '2022-03-08T11:24:53.401716Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'ec5ce334-d43b-4381-8ab6-828fbe4fab1e',
#    'ClOrdID': 'e214938a-870d-4e62-bccf-ef54a0afec78',
#    'SubmitTime': '2022-03-08T11:24:53.350343Z',
#    'ExecID': '05a4850e-c184-4ba8-b886-58b154b060f8',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T11:24:53.397000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-08T11:24:53.350343Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T12:17:08.581242Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'ddc352d4-e42f-4306-a2ca-cef408e508cc',
#    'ClOrdID': '4a3ad58d-f1a3-4258-9837-d07f62ffc6ff',
#    'SubmitTime': '2022-03-08T12:17:08.555672Z',
#    'ExecID': 'cab83652-a681-4888-90aa-68f8aa4138ca',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T12:17:08.565000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-08T12:17:08.555672Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T12:52:10.068543Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '59d91b26-639e-41ed-ab86-801af5b2666c',
#    'ClOrdID': '7cfbb8b3-2d70-4610-8bc8-c7e75e4d1916',
#    'SubmitTime': '2022-03-08T12:52:10.036627Z',
#    'ExecID': '88841e6d-a672-49f1-a5f2-34a6e82b5edf',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T12:52:10.053000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-08T12:52:10.036627Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T12:56:21.067633Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '1507158d-726a-47d1-8c44-69b54a2f74a7',
#    'ClOrdID': '2096024d-c3f4-49ae-9fbe-68ac1b85cade',
#    'SubmitTime': '2022-03-08T12:56:21.029282Z',
#    'ExecID': 'e0c0a5d5-b416-4b01-ad1d-10fb843953a7',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T12:56:21.046000Z',
#    'OrdStatus': 'New',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '1.00000000',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Revision': 2,
#    'LastRequestTimestamp': '2022-03-08T12:56:21.029282Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'New',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '5.81',
#      'LeavesQty': '1.00000',
#      'CumQty': '0',
#      'CumAmt': '0',
#      'CumFee': '0',
#      'AvgPx': '0',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T12:58:56.166466Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '7cac4a94-3758-4101-b5ea-3fca3c6ce24e',
#    'ClOrdID': 'f0f15269-00e4-46f6-b836-c863f80dc19b',
#    'SubmitTime': '2022-03-08T12:58:56.027877Z',
#    'ExecID': '73e1aeed-f5b1-49b9-a3c4-eee6fec09db6',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T12:58:56.145000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '38817.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '38799.53372950',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '38799.53372950',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '38799.53372950',
#    'Revision': 5,
#    'LastRequestTimestamp': '2022-03-08T12:58:56.027877Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '38799.5337295000',
#      'CumFee': '0',
#      'AvgPx': '38799.5337295',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T13:01:57.817285Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'dd0f57e8-f863-49bc-8a8e-ee2915f46e16',
#    'ClOrdID': '4aa4df08-8e0d-4897-86a6-9dac7295a48b',
#    'SubmitTime': '2022-03-08T13:01:57.754796Z',
#    'ExecID': '57f3bcc2-ecf2-4353-a87e-fdc5fa36e090',
#    'Side': 'Sell',
#    'TransactTime': '2022-03-08T13:01:57.782000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '5.81000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '38773.97591690',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '38773.97591690',
#    'CumFee': '7.754795183380',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '38766.22112172',
#    'Revision': 15,
#    'LastRequestTimestamp': '2022-03-08T13:01:57.754796Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '38773.9759169000',
#      'CumFee': '7.75479518338',
#      'AvgPx': '38773.9759169',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T13:12:30.972317Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '988fdc09-7526-433b-b72a-754c21b7a3ca',
#    'ClOrdID': '20057d39-91f0-43e2-9c50-90f2cc328f1c',
#    'SubmitTime': '2022-03-08T13:12:30.799817Z',
#    'ExecID': '806f3ee3-3f33-4134-8da5-651fe0080f58',
#    'Side': 'Buy',
#    'TransactTime': '2022-03-08T13:12:30.959000Z',
#    'OrdStatus': 'DoneForDay',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '39000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '1.00000000',
#    'AvgPx': '38720.11000000',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '38720.11000000',
#    'CumFee': '0',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'AvgPxAllIn': '38720.11000000',
#    'Revision': 4,
#    'LastRequestTimestamp': '2022-03-08T13:12:30.799817Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '1.00000',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '1.00000',
#      'CumAmt': '38720.1100000000',
#      'CumFee': '0',
#      'AvgPx': '38720.11',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]},
#   {'Timestamp': '2022-03-08T13:13:39.571444Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': 'aef9de69-639a-4444-87cd-023dafa1b39d',
#    'ClOrdID': '3a1b23ff-0ee0-42c3-b6cd-f249548e9092',
#    'SubmitTime': '2022-03-08T13:13:39.571444Z',
#    'ExecID': '3dbca53d-7525-4908-a3ad-2728a2cca19f',
#    'Side': 'Sell',
#    'OrdStatus': 'Rejected',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '37000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'OrdRejReason': 'BrokerOption',
#    'DecisionStatus': 'Active',
#    'Strategy': 'TWAP',
#    'Revision': 0,
#    'Markets': [{'Market': 'binance',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}],
#    'Text': 'Order duration must be at least 30s'},
#   {'Timestamp': '2022-03-08T13:14:10.727770Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '6bd333d0-4169-4297-ba81-8d2fe4106496',
#    'ClOrdID': 'f5b98b2f-b3b0-40e1-b9e6-c5319a943936',
#    'SubmitTime': '2022-03-08T13:14:10.727770Z',
#    'ExecID': '310288b0-b976-4432-a07c-29d85fb37c49',
#    'Side': 'Sell',
#    'OrdStatus': 'Rejected',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '37000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'OrdRejReason': 'BrokerOption',
#    'DecisionStatus': 'Active',
#    'Strategy': 'TWAP',
#    'Revision': 0,
#    'Markets': [{'Market': 'binance',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}],
#    'Text': 'Order duration must be at least 30s'},
#   {'Timestamp': '2022-03-08T13:19:51.615501Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '30a32467-3bf6-45c1-a944-265e720c22f2',
#    'ClOrdID': '2644df41-8aac-47e7-9fbf-0ce51d05f870',
#    'SubmitTime': '2022-03-08T13:19:51.615501Z',
#    'ExecID': '3658c9af-b154-4519-a589-e27787687c51',
#    'Side': 'Sell',
#    'OrdStatus': 'Rejected',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '37000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0',
#    'CumQty': '0',
#    'AvgPx': '0',
#    'TimeInForce': 'GoodTillCancel',
#    'CumAmt': '0',
#    'CumFee': '0',
#    'OrdRejReason': 'BrokerOption',
#    'DecisionStatus': 'Active',
#    'Strategy': 'TWAP',
#    'EndTime': '2022-03-08T16:20:00.000000Z',
#    'Revision': 0,
#    'Markets': [{'Market': 'binance',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}],
#    'Text': 'Start time should be before end time'},
#   {'Timestamp': '2022-03-08T15:59:42.493367Z',
#    'User': 'Daniil Tikhomirov',
#    'Symbol': 'BTC-USDT',
#    'OrderID': '47f7993e-ca8e-4dc6-a723-e030f559b4cc',
#    'ClOrdID': 'a08a1c85-525a-4e51-a119-af8da533c70e',
#    'SubmitTime': '2022-03-08T13:20:48.001311Z',
#    'ExecID': '21179f9b-16a9-4c8a-ab7a-8a7637a2f020',
#    'Side': 'Sell',
#    'TransactTime': '2022-03-08T15:59:42.485000Z',
#    'OrdStatus': 'PartiallyFilled',
#    'OrderQty': '1.00000000',
#    'OrdType': 'Limit',
#    'Price': '37000.00000000',
#    'Currency': 'BTC',
#    'LeavesQty': '0.01780000',
#    'CumQty': '0.98220000',
#    'AvgPx': '38739.12027245',
#    'TimeInForce': 'GoodTillCancel',
#    'LastFeeCurrency': 'USDT',
#    'CumAmt': '38049.56393160',
#    'CumFee': '5.077617119210',
#    'FeeCurrency': 'USDT',
#    'DecisionStatus': 'Active',
#    'AmountCurrency': 'USDT',
#    'Strategy': 'TWAP',
#    'AvgPxAllIn': '38733.95063580',
#    'EndTime': '2022-03-08T16:21:00.000000Z',
#    'AggressorSide': 'Sell',
#    'Revision': 91,
#    'LastRequestTimestamp': '2022-03-08T13:20:48.001311Z',
#    'Markets': [{'Market': 'binance',
#      'OrdStatus': 'Filled',
#      'OrderQty': '0.98220',
#      'OrdType': 'Limit',
#      'Price': '0',
#      'LeavesQty': '0',
#      'CumQty': '0.98220',
#      'CumAmt': '38049.5639316000',
#      'CumFee': '5.07761711921',
#      'AvgPx': '38739.12027245',
#      'FeeCurrency': 'USDT',
#      'MarketStatus': 'Online',
#      'LegIndex': 0,
#      'MarketAccount': 'binance/binance'}]}]}

# %%
post_order(endpoint, path, api_keys["apiKey"], api_keys["secret"])
# Out:
# {'ClOrdID': 'ef7c6a0a-e6df-4652-baaa-b27e209f88d7', 'Markets': ['binance'], 'OrderQty': '0.1000', 'Symbol': 'BTC-USDT', 'Currency': 'BTC', 'TransactTime': '2022-03-08T15:59:44.000000Z', 'OrdType': 'Limit', 'TimeInForce': 'GoodTillCancel', 'Price': '37000', 'Side': 'Sell', 'Strategy': 'TWAP', 'EndTime': '2022-03-08T16:21:00.000000Z'}
# 200

# %% [markdown]
# After posting the order one can check https://sandbox.talostrading.com/ to see how it is gradually being filled.

# %% [markdown]
# Interesting note: TWAP really decreases the number of paid fees.
# In comparison, the fees for a standard order (Limit) is 7.75 from an execution price 38773.97 (so, 0,02%), while TWAP order costs only 5.19 from an execution price 38737.24 (so, 0,014%).
