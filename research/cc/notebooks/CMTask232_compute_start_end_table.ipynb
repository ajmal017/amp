# %% [markdown]
# # Description

# %% [markdown]
# This notebook computes data statistics per exchange id and currency pair for a given vendor universe.

# %% [markdown]
# # Imports

# %%
import logging
import os

import core.config.config_ as ccocon
import helpers.dbg as hdbg
import helpers.env as henv
import helpers.printing as hprintin
import helpers.s3 as hs3
import im_v2.data.universe as imdatuniv
import research.cc.statistics as rccsta

# %%
hdbg.init_logger(verbosity=logging.INFO)

_LOG = logging.getLogger(__name__)

_LOG.info("%s", henv.get_system_signature()[0])

hprintin.config_notebook()
# Out:
# WARNING: Logger already initialized: skipping
# WARNING: Can't find version.txt, so using version=None
# >>ENV<<: is_inside_container=True: code_version=None, container_version=cmamp-1.0.0, is_inside_docker=True, is_inside_ci=False, CI_defined=True, CI=''
# >>ENV<<: AM_AWS_PROFILE=True AM_ECR_BASE_PATH=True AM_S3_BUCKET=True AM_TELEGRAM_TOKEN=True AWS_ACCESS_KEY_ID=False AWS_DEFAULT_REGION=False AWS_SECRET_ACCESS_KEY=False GH_ACTION_ACCESS_TOKEN=True
# -----------------------------------------------------------------------------
# This code is not in sync with the container:
# code_version='None' != container_version='cmamp-1.0.0'
# -----------------------------------------------------------------------------
# You need to:
# - merge origin/master into your branch with `invoke git_merge_master`
# - pull the latest container with `invoke docker_pull`
# # Git
#     branch_name='CMTask465_Remove_Sorting_from_compute_stats_for_universe'
#     hash='6e0fde89'
#     # Last commits:
#       * 6e0fde89 Grisha   CMTask455: move universe to `im_v2` (#459)                        (   3 hours ago) Wed Nov 17 17:21:45 2021  (HEAD -> CMTask465_Remove_Sorting_from_compute_stats_for_universe, origin/master, origin/HEAD, origin/CMTask470_Minor_todos_in_helpers_sql, master)
#       * 918e9353 cryptomtc Cmamp473_Convert_IM_scripts_to_invoke_tasks (#474)                (   3 hours ago) Wed Nov 17 17:19:37 2021
#       * 5a64889b Grisha   CMTask452: fix repo ref (#472)                                    (   4 hours ago) Wed Nov 17 16:33:37 2021
# # Machine info
#     system=Linux
#     node name=2aa3302efd5c
#     release=5.4.0-1057-aws
#     version=#60~18.04.1-Ubuntu SMP Thu Sep 9 20:38:09 UTC 2021
#     machine=x86_64
#     processor=x86_64
#     cpu count=4
#     cpu freq=scpufreq(current=2499.998, min=0.0, max=0.0)
#     memory=svmem(total=16596852736, available=8705830912, percent=47.5, used=7494934528, free=2720600064, active=9156108288, inactive=3429031936, buffers=476946432, cached=5904371712, shared=57282560, slab=1052282880)
#     disk usage=sdiskusage(total=133167038464, used=48854368256, free=84295892992, percent=36.7)
# # Packages
#     python: 3.8.10
#     gluonnlp: ?
#     gluonts: 0.6.7
#     joblib: 1.0.1
#     mxnet: 1.8.0
#     numpy: 1.21.1
#     pandas: 1.3.3
#     pyarrow: 5.0.0
#     scipy: 1.6.1
#     seaborn: 0.11.2
#     sklearn: 1.0
#     statsmodels: 0.12.2

# %% [markdown]
# # Config

# %%
def get_cmtask232_config() -> ccocon.Config:
    """
    Get task232-specific config.
    """
    config = ccocon.Config()
    # Load parameters.
    config.add_subconfig("load")
    config["load"]["aws_profile"] = "am"
    config["load"]["data_dir"] = os.path.join(hs3.get_path(), "data")
    # Data parameters.
    config.add_subconfig("data")
    config["data"]["data_type"] = "OHLCV"
    config["data"]["target_frequency"] = "T"
    config["data"]["universe_version"] = "v03"
    config["data"]["vendor"] = "CCXT"
    # Column names.
    config.add_subconfig("column_names")
    config["column_names"]["close_price"] = "close"
    config["column_names"]["currency_pair"] = "currency_pair"
    config["column_names"]["exchange_id"] = "exchange_id"
    return config


config = get_cmtask232_config()
print(config)
# Out:
# load:
#   aws_profile: am
#   data_dir: s3://alphamatic-data/data
# data:
#   data_type: OHLCV
#   target_frequency: T
#   universe_version: v03
#   vendor: CCXT
# column_names:
#   close_price: close
#   currency_pair: currency_pair
#   exchange_id: exchange_id

# %% [markdown]
# # Compute start-end table

# %% [markdown]
# ## Per exchange id and currency pair for a specified vendor

# %%
vendor_universe = imdatuniv.get_vendor_universe_as_tuples(
    config["data"]["universe_version"], config["data"]["vendor"]
)
vendor_universe
# Out:
# [ExchangeCurrencyTuple(exchange_id='binance', currency_pair='ADA/USDT'),
#  ExchangeCurrencyTuple(exchange_id='binance', currency_pair='AVAX/USDT'),
#  ExchangeCurrencyTuple(exchange_id='binance', currency_pair='BNB/USDT'),
#  ExchangeCurrencyTuple(exchange_id='binance', currency_pair='BTC/USDT'),
#  ExchangeCurrencyTuple(exchange_id='binance', currency_pair='DOGE/USDT'),
#  ExchangeCurrencyTuple(exchange_id='binance', currency_pair='EOS/USDT'),
#  ExchangeCurrencyTuple(exchange_id='binance', currency_pair='ETH/USDT'),
#  ExchangeCurrencyTuple(exchange_id='binance', currency_pair='LINK/USDT'),
#  ExchangeCurrencyTuple(exchange_id='binance', currency_pair='SOL/USDT'),
#  ExchangeCurrencyTuple(exchange_id='ftx', currency_pair='BNB/USDT'),
#  ExchangeCurrencyTuple(exchange_id='ftx', currency_pair='BTC/USDT'),
#  ExchangeCurrencyTuple(exchange_id='ftx', currency_pair='DOGE/USDT'),
#  ExchangeCurrencyTuple(exchange_id='ftx', currency_pair='ETH/USDT'),
#  ExchangeCurrencyTuple(exchange_id='ftx', currency_pair='LINK/USDT'),
#  ExchangeCurrencyTuple(exchange_id='ftx', currency_pair='SOL/USDT'),
#  ExchangeCurrencyTuple(exchange_id='ftx', currency_pair='XRP/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='ADA/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='AVAX/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='BNB/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='BTC/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='DOGE/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='EOS/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='ETH/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='FIL/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='LINK/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='SOL/USDT'),
#  ExchangeCurrencyTuple(exchange_id='gateio', currency_pair='XRP/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='ADA/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='AVAX/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='BNB/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='BTC/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='DOGE/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='EOS/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='ETH/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='FIL/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='LINK/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='SOL/USDT'),
#  ExchangeCurrencyTuple(exchange_id='kucoin', currency_pair='XRP/USDT')]

# %%
compute_start_end_stats = lambda data: rccsta.compute_start_end_stats(
    data, config
)

start_end_table = rccsta.compute_stats_for_universe(
    vendor_universe, config, compute_start_end_stats
)
# Out:
# Reading CCXT data for exchange id='binance', currencies='ADA/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/ADA_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='ADA/USDT'...
# Index length increased by 4520 = 1622000 - 1617480
# Reading CCXT data for exchange id='binance', currencies='AVAX/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/AVAX_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='AVAX/USDT'...
# Index length increased by 1224 = 517498 - 516274
# Reading CCXT data for exchange id='binance', currencies='BNB/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/BNB_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='BNB/USDT'...
# Index length increased by 4520 = 1622295 - 1617775
# Reading CCXT data for exchange id='binance', currencies='BTC/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/BTC_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='BTC/USDT'...
# Index length increased by 4519 = 1619641 - 1615122
# Reading CCXT data for exchange id='binance', currencies='DOGE/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/DOGE_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='DOGE/USDT'...
# Index length increased by 2869 = 1157600 - 1154731
# Reading CCXT data for exchange id='binance', currencies='EOS/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/EOS_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='EOS/USDT'...
# Index length increased by 4520 = 1622444 - 1617924
# Reading CCXT data for exchange id='binance', currencies='ETH/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/ETH_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='ETH/USDT'...
# Index length increased by 4520 = 1619889 - 1615369
# Reading CCXT data for exchange id='binance', currencies='LINK/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/LINK_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='LINK/USDT'...
# Index length increased by 3890 = 1402520 - 1398630
# Reading CCXT data for exchange id='binance', currencies='SOL/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/binance/SOL_USDT.csv.gz'...
# Processing CCXT data for exchange id='binance', currencies='SOL/USDT'...
# Index length increased by 1224 = 576140 - 574916
# Reading CCXT data for exchange id='ftx', currencies='BNB/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/BNB_USDT.csv.gz'...
# Processing CCXT data for exchange id='ftx', currencies='BNB/USDT'...
# Removed 36 / 763283 = 0.00% rows
# Index length increased by 212 = 763459 - 763247
# Reading CCXT data for exchange id='ftx', currencies='BTC/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/BTC_USDT.csv.gz'...
# Processing CCXT data for exchange id='ftx', currencies='BTC/USDT'...
# Removed 36 / 780707 = 0.00% rows
# Index length increased by 203 = 780874 - 780671
# Reading CCXT data for exchange id='ftx', currencies='DOGE/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/DOGE_USDT.csv.gz'...
# Processing CCXT data for exchange id='ftx', currencies='DOGE/USDT'...
# Removed 16 / 362591 = 0.00% rows
# Index length increased by 51 = 362626 - 362575
# Reading CCXT data for exchange id='ftx', currencies='ETH/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/ETH_USDT.csv.gz'...
# Processing CCXT data for exchange id='ftx', currencies='ETH/USDT'...
# Removed 36 / 780749 = 0.00% rows
# Index length increased by 202 = 780915 - 780713
# Reading CCXT data for exchange id='ftx', currencies='LINK/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/LINK_USDT.csv.gz'...
# Processing CCXT data for exchange id='ftx', currencies='LINK/USDT'...
# Removed 35 / 747070 = 0.00% rows
# Index length increased by 204 = 747239 - 747035
# Reading CCXT data for exchange id='ftx', currencies='SOL/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/SOL_USDT.csv.gz'...
# Processing CCXT data for exchange id='ftx', currencies='SOL/USDT'...
# Removed 31 / 607430 = 0.01% rows
# Index length increased by 182 = 607581 - 607399
# Reading CCXT data for exchange id='ftx', currencies='XRP/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/ftx/XRP_USDT.csv.gz'...
# Processing CCXT data for exchange id='ftx', currencies='XRP/USDT'...
# Removed 32 / 618181 = 0.01% rows
# Index length increased by 188 = 618337 - 618149
# Reading CCXT data for exchange id='gateio', currencies='ADA/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/ADA_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='ADA/USDT'...
# Index length=129365 has not changed
# Reading CCXT data for exchange id='gateio', currencies='AVAX/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/AVAX_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='AVAX/USDT'...
# Index length=129134 has not changed
# Reading CCXT data for exchange id='gateio', currencies='BNB/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/BNB_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='BNB/USDT'...
# Index length=129250 has not changed
# Reading CCXT data for exchange id='gateio', currencies='BTC/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/BTC_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='BTC/USDT'...
# Index length=129606 has not changed
# Reading CCXT data for exchange id='gateio', currencies='DOGE/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/DOGE_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='DOGE/USDT'...
# Index length=129422 has not changed
# Reading CCXT data for exchange id='gateio', currencies='EOS/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/EOS_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='EOS/USDT'...
# Index length=129192 has not changed
# Reading CCXT data for exchange id='gateio', currencies='ETH/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/ETH_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='ETH/USDT'...
# Index length=129606 has not changed
# Reading CCXT data for exchange id='gateio', currencies='FIL/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/FIL_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='FIL/USDT'...
# Index length=129480 has not changed
# Reading CCXT data for exchange id='gateio', currencies='LINK/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/LINK_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='LINK/USDT'...
# Index length=129307 has not changed
# Reading CCXT data for exchange id='gateio', currencies='SOL/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/SOL_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='SOL/USDT'...
# Index length=129595 has not changed
# Reading CCXT data for exchange id='gateio', currencies='XRP/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/gateio/XRP_USDT.csv.gz'...
# Processing CCXT data for exchange id='gateio', currencies='XRP/USDT'...
# Index length=129537 has not changed
# Reading CCXT data for exchange id='kucoin', currencies='ADA/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/ADA_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='ADA/USDT'...
# Index length=1158284 has not changed
# Reading CCXT data for exchange id='kucoin', currencies='AVAX/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/AVAX_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='AVAX/USDT'...
# Index length=280129 has not changed
# Reading CCXT data for exchange id='kucoin', currencies='BNB/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/BNB_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='BNB/USDT'...
# Index length=1180057 has not changed
# Reading CCXT data for exchange id='kucoin', currencies='BTC/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/BTC_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='BTC/USDT'...
# Index length increased by 94496 = 1619786 - 1525290
# Reading CCXT data for exchange id='kucoin', currencies='DOGE/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/DOGE_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='DOGE/USDT'...
# Index length=314817 has not changed
# Reading CCXT data for exchange id='kucoin', currencies='EOS/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/EOS_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='EOS/USDT'...
# Index length increased by 232290 = 1621431 - 1389141
# Reading CCXT data for exchange id='kucoin', currencies='ETH/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/ETH_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='ETH/USDT'...
# Index length increased by 117548 = 1619960 - 1502412
# Reading CCXT data for exchange id='kucoin', currencies='FIL/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/FIL_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='FIL/USDT'...
# Index length=482205 has not changed
# Reading CCXT data for exchange id='kucoin', currencies='LINK/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/LINK_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='LINK/USDT'...
# Index length=563664 has not changed
# Reading CCXT data for exchange id='kucoin', currencies='SOL/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/SOL_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='SOL/USDT'...
# Index length=60509 has not changed
# Reading CCXT data for exchange id='kucoin', currencies='XRP/USDT' from file='s3://alphamatic-data/data/ccxt/20210924/kucoin/XRP_USDT.csv.gz'...
# Processing CCXT data for exchange id='kucoin', currencies='XRP/USDT'...
# Index length increased by 107007 = 1464388 - 1357381

# %%
# Post-process results.
cols_to_sort_by = ["coverage", "longest_not_nan_seq_perc"]
cols_to_round = [
    "coverage",
    "avg_data_points_per_day",
    "longest_not_nan_seq_perc",
]
stats_table = rccsta.postprocess_stats_table(
    start_end_table, cols_to_sort_by, cols_to_round
)
stats_table
# Out:
#    exchange_id currency_pair             min_timestamp             max_timestamp n_data_points   coverage days_available avg_data_points_per_day longest_not_nan_seq_days longest_not_nan_seq_perc longest_not_nan_seq_start_date longest_not_nan_seq_end_date vendor
# 32      kucoin      EOS/USDT 2018-08-16 20:10:00-04:00 2021-09-15 20:00:00-04:00       1389141  85.673766           1125                1234.792                      941                83.571055      2019-02-17 18:54:00-05:00    2021-09-15 20:00:00-04:00   CCXT
# 37      kucoin      XRP/USDT 2018-12-03 11:58:00-05:00 2021-09-15 11:25:00-04:00       1357381  92.692715           1016             1336.004921                      940                92.498368      2019-02-17 18:51:00-05:00    2021-09-15 11:25:00-04:00   CCXT
# 33      kucoin      ETH/USDT 2018-08-16 20:01:00-04:00 2021-09-14 19:20:00-04:00       1502412  92.743771           1124              1336.66548                      939                83.555458      2019-02-17 18:56:00-05:00    2021-09-14 19:20:00-04:00   CCXT
# 30      kucoin      BTC/USDT 2018-08-16 20:00:00-04:00 2021-09-14 16:25:00-04:00       1525290  94.166143           1124             1357.019573                      939                 83.55363      2019-02-17 18:56:00-05:00    2021-09-14 16:25:00-04:00   CCXT
# 6      binance      ETH/USDT 2018-08-16 20:00:00-04:00 2021-09-14 18:08:00-04:00       1615369  99.720969           1124             1437.161032                      155                13.780574      2020-06-28 01:30:00-04:00    2020-11-30 00:59:00-05:00   CCXT
# 3      binance      BTC/USDT 2018-08-16 20:00:00-04:00 2021-09-14 14:00:00-04:00       1615122  99.720988           1124             1436.941281                      155                13.782684      2020-06-28 01:30:00-04:00    2020-11-30 00:59:00-05:00   CCXT
# 0      binance      ADA/USDT 2018-08-16 20:00:00-04:00 2021-09-16 05:19:00-04:00       1617480  99.721332           1126             1436.483126                      155                13.762639      2020-06-28 01:30:00-04:00    2020-11-30 00:59:00-05:00   CCXT
# 2      binance      BNB/USDT 2018-08-16 20:00:00-04:00 2021-09-16 10:14:00-04:00       1617775  99.721382           1126             1436.745115                      155                13.760136      2020-06-28 01:30:00-04:00    2020-11-30 00:59:00-05:00   CCXT
#
# Looking at the results we can see that all the exchanges except for Bitfinex have significantly big longest not-NaN sequence (>13% at least) in combine with high data coverage (>85%). Bitfinex has a very low data coverage and its longest not-NaN sequence lengths are less than 1 day long and comprise less than 1% of the original data. This means that Bitfinex data spottiness is too scattered and we should exclude it from our analysis until we get clearer data for it.

# %%
_LOG.info(
    "The number of unique exchange and currency pair combinations=%s",
    start_end_table.shape[0],
)
start_end_table
# Out:
# The number of unique exchange and currency pair combinations=48
#    exchange_id currency_pair             min_timestamp             max_timestamp  n_data_points  coverage  days_available  avg_data_points_per_day  longest_not_nan_seq_days  longest_not_nan_seq_perc longest_not_nan_seq_start_date longest_not_nan_seq_end_date vendor
# 13    bitfinex      EOS/USDT 2019-04-12 06:02:00-04:00 2021-09-20 06:00:00-04:00         177355     13.81             891                   199.05                         0                      0.01      2021-05-11 08:50:00-04:00    2021-05-11 11:14:00-04:00   CCXT
# 15    bitfinex      FIL/USDT 2020-10-15 14:54:00-04:00 2021-09-19 21:48:00-04:00         114422     23.42             339                   337.53                         0                      0.02      2021-05-13 04:42:00-04:00    2021-05-13 06:13:00-04:00   CCXT
# 10    bitfinex     AVAX/USDT 2020-09-23 08:03:00-04:00 2021-09-20 07:02:00-04:00         124075     23.80             361                   343.70                         0                      0.14      2021-09-07 15:54:00-04:00    2021-09-08 03:51:00-04:00   CCXT
# 9     bitfinex      ADA/USDT 2020-08-06 06:11:00-04:00 2021-09-19 23:24:00-04:00         166401     28.20             409                   406.85                         0                      0.03      2021-03-18 10:51:00-04:00    2021-03-18 13:21:00-04:00   CCXT
# 16    bitfinex     LINK/USDT 2020-08-21 05:04:00-04:00 2021-09-20 00:21:00-04:00         165794     29.16             394                   420.80                         0                      0.03      2021-09-11 09:43:00-04:00    2021-09-11 12:53:00-04:00   CCXT
# 18    bitfinex      XRP/USDT 2020-12-18 04:53:00-05:00 2021-09-19 20:57:00-04:00         152880     38.52             275                   555.93                         0                      0.06      2021-04-13 11:32:00-04:00    2021-04-13 15:17:00-04:00   CCXT
# 14    bitfinex      ETH/USDT 2019-03-11 06:03:00-04:00 2021-09-19 19:13:00-04:00         622353     46.80             923                   674.27                         1                      0.14      2021-05-19 09:59:00-04:00    2021-05-20 15:55:00-04:00   CCXT
# 12    bitfinex     DOGE/USDT 2021-04-21 07:03:00-04:00 2021-09-19 22:39:00-04:00         106829     48.92             151                   707.48                         0                      0.13      2021-09-11 09:42:00-04:00    2021-09-11 14:20:00-04:00   CCXT
# 17    bitfinex      SOL/USDT 2021-02-25 06:10:00-05:00 2021-09-19 20:03:00-04:00         154215     51.85             206                   748.62                         0                      0.14      2021-09-08 12:33:00-04:00    2021-09-08 19:27:00-04:00   CCXT
# 11    bitfinex      BTC/USDT 2019-03-11 06:05:00-04:00 2021-09-19 18:22:00-04:00         715022     53.77             923                   774.67                         1                      0.17      2021-05-18 18:35:00-04:00    2021-05-20 07:16:00-04:00   CCXT
# 42      kucoin      EOS/USDT 2018-08-16 20:10:00-04:00 2021-09-15 20:00:00-04:00        1389141     85.67            1125                  1234.79                       941                     83.57      2019-02-17 18:54:00-05:00    2021-09-15 20:00:00-04:00   CCXT
# 38      kucoin     AVAX/USDT 2021-03-05 05:00:00-05:00 2021-09-15 18:48:00-04:00         280129    100.00             194                  1443.96                       194                    100.00      2021-03-05 05:00:00-05:00    2021-09-15 18:48:00-04:00   CCXT
# 39      kucoin      BNB/USDT 2019-06-19 06:00:00-04:00 2021-09-15 17:36:00-04:00        1180057    100.00             819                  1440.85                       819                    100.00      2019-06-19 06:00:00-04:00    2021-09-15 17:36:00-04:00   CCXT
# 41      kucoin     DOGE/USDT 2021-02-08 22:00:00-05:00 2021-09-15 13:56:00-04:00         314817    100.00             218                  1444.11                       218                    100.00      2021-02-08 22:00:00-05:00    2021-09-15 13:56:00-04:00   CCXT
# 44      kucoin      FIL/USDT 2020-10-15 13:25:00-04:00 2021-09-15 10:09:00-04:00         482205    100.00             334                  1443.73                       334                    100.00      2020-10-15 13:25:00-04:00    2021-09-15 10:09:00-04:00   CCXT
# 45      kucoin     LINK/USDT 2020-08-20 06:00:00-04:00 2021-09-15 16:23:00-04:00         563664    100.00             391                  1441.60                       391                    100.00      2020-08-20 06:00:00-04:00    2021-09-15 16:23:00-04:00   CCXT
# 46      kucoin      SOL/USDT 2021-08-04 06:00:00-04:00 2021-09-15 06:28:00-04:00          60509    100.00              42                  1440.69                        42                    100.00      2021-08-04 06:00:00-04:00    2021-09-15 06:28:00-04:00   CCXT

# %% [markdown]
# ## Per currency pair

# %%
currency_start_end_table = rccsta.compute_start_end_table_by_currency(
    start_end_table
)
currency_start_end_table
# Out:
# The number of unique currency pairs=11
#    currency_pair             min_timestamp             max_timestamp                               exchange_id  days_available
# 0       BNB/USDT 2018-08-16 20:00:00-04:00 2021-09-21 21:13:00-04:00            [binance, ftx, gateio, kucoin]            1132
# 1       BTC/USDT 2018-08-16 20:00:00-04:00 2021-09-21 17:13:00-04:00  [bitfinex, kucoin, binance, ftx, gateio]            1131
# 2       ETH/USDT 2018-08-16 20:00:00-04:00 2021-09-21 17:54:00-04:00  [bitfinex, kucoin, binance, ftx, gateio]            1131
# 3       ADA/USDT 2018-08-16 20:00:00-04:00 2021-09-20 12:39:00-04:00       [bitfinex, binance, gateio, kucoin]            1130
# 4       EOS/USDT 2018-08-16 20:00:00-04:00 2021-09-20 12:39:00-04:00       [bitfinex, kucoin, binance, gateio]            1130
# 5       XRP/USDT 2018-12-03 11:58:00-05:00 2021-09-21 19:13:00-04:00           [bitfinex, kucoin, ftx, gateio]            1023
# 6      LINK/USDT 2019-01-16 05:00:00-05:00 2021-09-21 20:32:00-04:00  [bitfinex, binance, ftx, gateio, kucoin]             979
# 7      DOGE/USDT 2019-07-05 08:00:00-04:00 2021-09-21 19:51:00-04:00  [bitfinex, binance, ftx, gateio, kucoin]             809
# 8       SOL/USDT 2020-07-26 20:13:00-04:00 2021-09-21 18:33:00-04:00  [bitfinex, binance, ftx, gateio, kucoin]             421
# 9      AVAX/USDT 2020-09-22 02:30:00-04:00 2021-09-20 12:39:00-04:00       [bitfinex, binance, gateio, kucoin]             363
# 10      FIL/USDT 2020-10-15 13:25:00-04:00 2021-09-20 12:39:00-04:00                [bitfinex, gateio, kucoin]             339
